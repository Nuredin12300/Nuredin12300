# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import random

x1 = [10,10,100,100,10,10,100,100,10]
y1 = [0,30,30,0,0,20,20,10,10]
plt.plot(x1,y1,'r')

x2 = [10,10,100,100,10,10,100,100,10]
y2 = [30,60,60,30,30,50,50,40,40]
plt.plot(x2,y2,'y')

x3 = [10,10,100,100,10,10,100,100,10]
y3 = [60,90,90,60,60,80,80,70,70]
plt.plot(x3,y3,'g')

for i in range(10000):
    x4 = random.uniform(10.5,99.4)
    y4 = random.uniform(61.5,89.2)
    plt.plot(x4,y4,'o',color="green")
for i in range(10000):
    x5 = random.uniform(10.5,99.4)
    y5 = random.uniform(31.5,59.5)
    plt.plot(x5,y5,'o',color="yellow")
for i in range(10000):
    x6 = random.uniform(10.5,99.4)
    y6 = random.uniform(0.4,29.5)
    plt.plot(x6,y6,'o',color="red")
for i in range(10000):
    x7 = random.uniform(10.5,99.4)
    y7 = random.uniform(60.1,60.1)
    plt.plot(x7,y7,'o',color="green")
for i in range(10000):
    x8 = random.uniform(10.5,99.4)
    y8 = random.uniform(31.5,31.5)
    plt.plot(x8,y8,'o',color="yellow")
for i in range(10000):
    x9 = random.uniform(10.5,99.4)
    y9 = random.uniform(0,0)
    plt.plot(x9,y9,'o',color="red")
for i in range(10000):
    x11 = random.uniform(10.5,99.4)
    y11 = random.uniform(89.5,89.2)
    plt.plot(x11,y11,'o',color="green")
for i in range(10000):
    x12 = random.uniform(10.5,10.5)
    y12 = random.uniform(31.5,56.7)
    plt.plot(x12,y12,'o',color="yellow")      
for i in range(10000):
    x5 = random.uniform(99.4,99.4)
    y5 = random.uniform(31.5,56.7)
    plt.plot(x5,y5,'o',color="yellow")      
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import random

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

for i in range(10000):
    x4 = random.uniform(-2.5,2.5)
    y4 = random.uniform(0.5,1.5)
    plt.plot(x4,y4,'o',color="green")
for i in range(10000):
    x5 = random.uniform(-2.5,2.5)
    y5 = random.uniform(-0.5,0.5)
    plt.plot(x5,y5,'o',color="yellow")
for i in range(10000):
    x6 = random.uniform(-2.5,2.5)
    y6 = random.uniform(-1.5,-0.5)
    plt.plot(x6,y6,'o',color="red")
for i in range(10000):
    x8 = random.uniform(-2.5,2.5)
    y8 = random.uniform(1.5,1.5)
    plt.plot(x8,y8,'o',color="green")
for i in range(10000):
    x9 = random.uniform(-2.5,2.5)
    y9 = random.uniform(0.5,0.5)
    plt.plot(x9,y9,'o',color="green")
for i in range(10000):
    x10 = random.uniform(-2.5,2.5)
    y10 = random.uniform(-0.5,-0.5)
    plt.plot(x10,y10,'o',color="yellow")
for i in range(10000):
    x11 = random.uniform(-2.5,2.5)
    y11 = random.uniform(-1.5,-1.5)
    plt.plot(x11,y11,'o',color="red")
for i in range(10000):
    x12 = random.uniform(-2.5,-2.5)
    y12 = random.uniform(1.5,0.5)
    plt.plot(x12,y12,'o',color="green")
for i in range(10000):
    x13 = random.uniform(-2.5,-2.5)
    y13 = random.uniform(0.3,-0.5)
    plt.plot(x13,y13,'o',color="yellow")
for i in range(1000):
    x14 = random.uniform(-2.5,-2.5)
    y14 = random.uniform(-0.65,-1.5)
    plt.plot(x14,y14,'o',color="red")
for i in range(1000):
    x15 = random.uniform(2.5,2.5)
    y15 = random.uniform(1.5,0.5)
    plt.plot(x15,y15,'o',color="green")
for i in range(1000):
    x16 = random.uniform(2.5,2.5)
    y16 = random.uniform(0.3,-0.7)
    plt.plot(x16,y16,'o',color="yellow")
for i in range(1000):
    x17 = random.uniform(2.5,2.5)
    y17 = random.uniform(-0.6,-1.5)
    plt.plot(x17,y17,'o',color="red")
for i in range(10000):
    x7=2*random.random()-1
    y7=2*random.random()-1
    c1 = x7**2+y7**2
    if c1<0.6 and c1>-0.6:     
        plt.plot(x7,y7,'o',color="blue")
        c1+=1
x = [-0.47,0.47]
y = [0.15,0.15]
plt.plot(x,y,'y')        
x1 = [0.47,-0.3]
y1 = [0.15,-0.47]
plt.plot(x1,y1,'y')
x2 = [-0.3,0]
y2 = [-0.47,0.5]
plt.plot(x2,y2,'y')
x3 = [0,0.3]
y3 = [0.5,-0.47]
plt.plot(x3,y3,'y')
x18 = [0.3,-0.47]
y18 = [-0.47,0.15]
plt.plot(x18,y18,'y')
x19 = [0.2,0.4]
y19 = [0.2,0.4]
plt.plot(x19,y19,'y')
x20 = [-0.15,-0.3]
y20 = [0.2,0.4]
plt.plot(x20,y20,'y')
x21 = [-0.23,-0.45]
y21 = [-0.1,-0.22]
plt.plot(x21,y21,'y')
x22 = [0.05,0.05]
y22 = [-0.3,-0.5]
plt.plot(x22,y22,'y')
x23 = [0.3,0.5]
y23 = [-0.1,-0.18]
plt.plot(x23,y23,'y')
ax.set_aspect('equal',adjustable = 'box')
plt.show()
